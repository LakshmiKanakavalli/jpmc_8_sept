-- %%
SELECT * FROM json.`/Volumes/dev/valli/raw/1.json`

-- %%
%python
df=spark.read.json("/Volumes/dev/valli/raw/1.json")

-- %%
%python
df.write.mode("overwrite").saveAsTable("dev.valli.medical_py")

-- %%
desc extended dev.valli.medical_py

-- %% [markdown]
-- # **Lazy Evalution**
-- ## Transformation
--
--   - select
--   - filter /where
--   - withColumnRenamed
--   - withColumn
-- Action
--
--     show
--     display
--     write

-- %%
%python
df.show()

-- %%
%python
df.display()

-- %%
%python
df.createOrReplaceTempView("medical_view")

-- %%
select * from medical_view

-- %%
%python
df.where("patient_id= 'patient12345'")

-- %%
%python
df.where("patient_id= 'patient12345'").explain(True)

-- %%
%python
df.where("patient_id= 'patient12345'").display()

-- %%
%python
df1=df.select("device_id","location")

-- %%
%python
df.withColumnRenamed("device_id","deviceid")#.display()

-- %%
%python
df.printSchema()

-- %%
%python
from pyspark.sql.functions import *

-- %%
%python
df1=df.withColumn("ingestion_date",current_date())

-- %%
%python
df.withColumn("sensor_type",upper("sensor_type")).display()

-- %%
%python
df1.display()
