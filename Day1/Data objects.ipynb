-- %%
%sql
--start of day1
use catalog dev;
create schema if not exists valli;
use schema valli;

-- %%
create table test (id int)

-- %%
desc extended valli.test

-- %%
CREATE volume dev.valli.input_files

-- %%
create or replace function dev.valli.full_name(fore_name string, last_name string)
returns string
return concat(fore_name," ", last_name )

-- %%
select dev.valli.full_name('valli','Pentela') as Fullname
